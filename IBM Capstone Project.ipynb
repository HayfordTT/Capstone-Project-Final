# %% [markdown]
# # The Best Tourist Venues Around South Africa

# %% [markdown]
# **Hayford Tetteh** <br>
# Capstone Project The Battle of Neighborhoods (Week 1) <br>
# IBM Data Science Professional Certificate <br>

# %% [markdown]
# ![South-Africa-Landscape.jpg](attachment:South-Africa-Landscape.jpg)

# %% [markdown]
# Now that you have been equipped with the skills and the tools to use location data to explore a geographical location, over the course of two weeks, you will have the opportunity to be as creative as you want and come up with an idea to leverage the Foursquare location data to explore or compare neighborhoods or cities of your choice or to come up with a problem that you can use the Foursquare location data to solve. If you cannot think of an idea or a problem, here are some ideas to get you started:
#
# In Module 3, we explored New York City and the city of Toronto and segmented and clustered their neighborhoods. Both cities are very diverse and are the financial capitals of their respective countries. One interesting idea would be to compare the neighborhoods of the two cities and determine how similar or dissimilar they are. Is New York City more like Toronto or Paris or some other multicultural city? I will leave it to you to refine this idea. In a city of your choice, if someone is looking to open a restaurant, where would you recommend that they open it? Similarly, if a contractor is trying to start their own business, where would you recommend that they setup their office? These are just a couple of many ideas and problems that can be solved using location data in addition to other datasets. No matter what you decide to do, make sure to provide sufficient justification of why you think what you want to do or solve is important and why would a client or a group of people be interested in your project.

# %% [markdown]
# ### Table of Contents
# #### 1. A description of the problem and a discussion of the background. (15 marks)
# #### 2. A description of the data and how it will be used to solve the problem. (15 marks)

# %% [markdown]
# #### 1. Discussion and Background of the Business Problem: Exploring The Business Potentials in Operating a Restaurant in a Selective City in South Africa.
#
# <br>
# South Africa, called by some people the 'Rainbow Nation', a title that captures its diversity and 11 official languages. September is, since 1994 officially heritage month, when the histories and cultural practices of all its peoples are celebrated and due recognition given to the men and women who have contributed to the heritage and culture of the nation. Freedom of cultural, religious and linguistic expression is enshrined in the Constitution of the Republic of South Africa. South Africa is a country where creative expression flourishes and its cultural diversity are embodied in its arts and culture.
#
#
# Narh Bleponi Tourism Company Based In Ghana, is expanding thier operations to South Africa due the rich cultural, ethnic and religious diversity. The company want to identify and advertise all the best venues in and around Cape town, Johannesburg and Durban to recommend and attract tourists.
# For a new company to operate in provinces such as Western Cape, Kwazulu Natal and Gauteng, knowing ahead of time there are potential competitors and limited information about venues is an excellent solution to the ever present business problem of uncertainty. An insight with rescpect to the folloiwing venues and sites will be the central focus of the project. We can mitigate this any form of uncertainty through leveraging data gathered from FourSquare's API, specifically, we are able to scrape "likes or score" data of different venues directly from the API as well as their location and categories. The question we will try to address is, how many venues can we recommend to tourist base on likes and score ratings and where are thses venues located in and around Cape Town, Johannesburg and Durban?
# In addition to venue information, the company does not know which city to select as thier headquarters. The company would prefer to slect one the these cities as their headquarters, what factors must be used to select this city?.

# %% [markdown]
# ### 2. A description of the data and how it will be used to solve the problem.

# %% [markdown]
# #### Download and Explore Dataset
# In this section we will first retrieve the geographical coordinates of the neighborhood in the three cities (Cape Towm, Johannesburg, and Durban). Then, we will leverage the FourSquare API to obtain URLs that lead to the raw data in JSON form. We will speerately scrape the raw data in these URLs in order to retrieve the following columns: "name", "categories", "latitude", "longitude", 'postalCode' and "id" for each city. We can also provide another column ("City") to indicate which city the venues are located.
# <br>
#
# It is important to note that the extracts are not of every diferent categories in those cities but rather all the venues that are of interest to the company will be icluded the data. However, the extraction from the FourSquare API actually obtains venue data so it will include venues other than restaurants such as concert halls, stores, libraries etc. As such, this means that the data will need to be further cleaned somewhat manually by removing all of the uninterested rows. Once this is complete, we will save it as pandas datafame file('CSV')
#
#
# The data will be sourced from various into tables, of which would be converted to pandas dataframes then manipulated in this notebook. The data generated in this lab as well as relevant data generated in two previous Labs have been cleaned and stored as csv files with geo-location coordinates, their corresponding IPython notebooks and maps in html format can be forked at Github Data Sources & Types: The data will be used to cluster and compare the three cities, then rank the neighborhoods from the selected boroughs. In prior labs these two cleaned data sets were created, you can download them from Github they have a list of the following neighborhoods with their geo-ordinates as well as venues, gleaned with the Folium App. Neighborhoods, Geo-Coordinates & Venues:

# %% [markdown]
# Importing all needed Libraries

# %%
# !conda update --all
# Out:
# Solving environment: done
#
# ## Package Plan ##
#
#   environment location: /opt/conda/envs/Python36
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     markupsafe-1.1.1           |   py36h7b6447c_0          29 KB
#     typed-ast-1.4.1            |   py36h7b6447c_0         208 KB
#     ld_impl_linux-64-2.33.1    |       h53a641e_7         645 KB
#     xlsxwriter-1.2.8           |             py_0         108 KB
#     colorama-0.4.3             |             py_0          20 KB
#     soupsieve-2.0              |             py_0          33 KB
#     intervaltree-3.0.2         |             py_0          25 KB
#     scikit-learn-0.22.1        |   py36hd81dba3_0         7.1 MB
#     libgcc-ng-9.1.0            |       hdf63c60_0         8.1 MB
#     zipp-2.2.0                 |             py_0          12 KB
#     jedi-0.15.2                |           py36_0         768 KB
# ...

# %%
# !pip install folium
import numpy as np 

import pandas as pd 
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

import json

from geopy.geocoders import Nominatim 

import requests
from pandas.io.json import json_normalize 


import matplotlib.cm as cm
import matplotlib.colors as colors


import folium 

from urllib.request import urlopen
from bs4 import BeautifulSoup


import matplotlib.pyplot as plt
import pylab as pl

from sklearn import linear_model
from sklearn.metrics import jaccard_similarity_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.metrics import log_loss
from sklearn.metrics import r2_score
from sklearn.metrics import mean_squared_error, r2_score
import itertools


print('Libraries imported.')
# Out:
# ...
# Libraries imported.

# %% [markdown]
# Getting Geo coordinates of Neighborhoods Cape Town, Durban and Sandton

# %%
connection1 = 'False Bay, South Africa'

geolocator = Nominatim()
location1 = geolocator.geocode(connection1)
latitude1 = location1.latitude
longitude1 = location1.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection1, latitude1, longitude1))


connection2 = 'Bellville, South Africa'

geolocator = Nominatim()
location2 = geolocator.geocode(connection2)
latitude2 = location2.latitude
longitude2 = location2.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection2, latitude2, longitude2))


connection3 = 'City Bowl, South Africa'

geolocator = Nominatim()
location3 = geolocator.geocode(connection3)
latitude3 = location3.latitude
longitude3 = location3.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection3, latitude3, longitude3))


connection4 = 'Atlantic Seaboard, South Africa'

geolocator = Nominatim()
location4 = geolocator.geocode(connection4)
latitude4 = location4.latitude
longitude4 = location4.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection4, latitude4, longitude4))


connection5 = 'Goodwood , South Africa'

geolocator = Nominatim()
location5 = geolocator.geocode(connection5)
latitude5 = location5.latitude
longitude5 = location5.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection5, latitude5, longitude5))


connection6 = ' Brackenfell, South Africa'

geolocator = Nominatim()
location6 = geolocator.geocode(connection6)
latitude6 = location6.latitude
longitude6 = location6.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection6, latitude6, longitude6))


connection7 = 'Simons Town, South Africa'

geolocator = Nominatim()
location7 = geolocator.geocode(connection7)
latitude7 = location7.latitude
longitude7 = location7.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection7, latitude7, longitude7))


connection8 = 'Hout Bay, South Africa'

geolocator = Nominatim()
location8 = geolocator.geocode(connection8)
latitude8 = location8.latitude
longitude8 = location8.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection8, latitude8, longitude8))


connection9 = 'Green Point, South Africa'

geolocator = Nominatim()
location9 = geolocator.geocode(connection9)
latitude9 = location9.latitude
longitude9 = location9.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection9, latitude9, longitude9))


connection10 = 'Constantia, South Africa'

geolocator = Nominatim()
location10 = geolocator.geocode(connection10)
latitude10 = location10.latitude
longitude10 = location10.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection10, latitude10, longitude10))


connection11 = 'Blue Downs, South Africa'

geolocator = Nominatim()
location11 = geolocator.geocode(connection11)
latitude11 = location11.latitude
longitude11 = location11.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection11, latitude11, longitude11))


connection12 = 'Parow, South Africa'

geolocator = Nominatim()
location12 = geolocator.geocode(connection12)
latitude12 = location12.latitude
longitude12 = location12.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection12, latitude12, longitude12))

connection13 = 'Durbanville , South Africa'

geolocator = Nominatim()
location13 = geolocator.geocode(connection13)
latitude13 = location13.latitude
longitude13 = location13.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection13, latitude13, longitude13))


connection14 = 'Muizenberg, South Africa'

geolocator = Nominatim()
location14 = geolocator.geocode(connection12)
latitude14 = location14.latitude
longitude14 = location14.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection14, latitude14, longitude14))


connection15 = 'Fish Hoek, South Africa'

geolocator = Nominatim()
location15 = geolocator.geocode(connection15)
latitude15 = location15.latitude
longitude15 = location15.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection15, latitude15, longitude15))


connection16 = 'Milnerto, South Africa'

geolocator = Nominatim()
location16 = geolocator.geocode(connection12)
latitude16 = location16.latitude
longitude16 = location16.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection16, latitude16, longitude16))

connection17 = 'Wynberg, South Africa'

geolocator = Nominatim()
location17 = geolocator.geocode(connection17)
latitude17 = location17.latitude
longitude17 = location17.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection17, latitude17, longitude17))

connection18 = 'Bedfordview, South Africa'

geolocator = Nominatim()
location18 = geolocator.geocode(connection18)
latitude18 = location18.latitude
longitude18 = location18.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection18, latitude18, longitude18))


connection19 = 'Blouberg , South Africa'

geolocator = Nominatim()
location19 = geolocator.geocode(connection19)
latitude19 = location19.latitude
longitude19 = location19.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection19, latitude19, longitude19))

connection20 = 'Kuils River, South Africa'

geolocator = Nominatim()
location20 = geolocator.geocode(connection20)
latitude20 = location20.latitude
longitude20 = location20.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection20, latitude20, longitude20))


#Neighborhoods in Johannnesburg
connection21 = 'Randburg, South Africa'

geolocator = Nominatim()
location21 = geolocator.geocode(connection21)
latitude21 = location21.latitude
longitude21 = location21.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection21, latitude21, longitude21))


connection22 = 'Fourways, South Africa'

geolocator = Nominatim()
location22 = geolocator.geocode(connection22)
latitude22 = location22.latitude
longitude22 = location22.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection22, latitude22, longitude22))


connection23 = 'Rivonia, South Africa'

geolocator = Nominatim()
location23 = geolocator.geocode(connection23)
latitude23 = location23.latitude
longitude23 = location23.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection23, latitude23, longitude23))


connection24 = 'Johannesburg Central, South Africa'

geolocator = Nominatim()
location24 = geolocator.geocode(connection24)
latitude24 = location24.latitude
longitude24 = location24.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection24, latitude24, longitude24))


connection25 = 'Bruma, South Africa'

geolocator = Nominatim()
location25 = geolocator.geocode(connection25)
latitude25 = location25.latitude
longitude25 = location25.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection25, latitude25, longitude25))


connection26 = 'Johannesburg South, South Africa'

geolocator = Nominatim()
location26 = geolocator.geocode(connection26)
latitude26 = location26.latitude
longitude26 = location26.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection26, latitude26, longitude26))


connection27 = 'Northcliff, South Africa'

geolocator = Nominatim()
location27 = geolocator.geocode(connection27)
latitude27 = location27.latitude
longitude27 = location27.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection27, latitude27, longitude27))


connection28 = 'Northriding, South Africa'

geolocator = Nominatim()
location28 = geolocator.geocode(connection28)
latitude28 = location28.latitude
longitude28 = location28.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection28, latitude28, longitude28))


connection29 = 'Lanseria, South Africa'

geolocator = Nominatim()
location29 = geolocator.geocode(connection29)
latitude29 = location29.latitude
longitude29 = location29.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection29, latitude29, longitude29))


connection30 = 'Rose Bank , South Africa'

geolocator = Nominatim()
location30 = geolocator.geocode(connection30)
latitude30 = location30.latitude
longitude30 = location30.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection30, latitude30, longitude30))


#Neighborhood in Durban
connection31 = 'Parktown, South Africa'

geolocator = Nominatim()
location31 = geolocator.geocode(connection31)
latitude31 = location31.latitude
longitude31 = location31.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection31, latitude31, longitude31))



connection32 = 'Sandton, South Africa'

geolocator = Nominatim()
location32 = geolocator.geocode(connection32)
latitude32 = location32.latitude
longitude32 = location32.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection32, latitude32, longitude32))


connection33 = 'Ferndale, South Africa'

geolocator = Nominatim()
location33 = geolocator.geocode(connection33)
latitude33 = location33.latitude
longitude33 = location33.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection33, latitude33, longitude33))


connection34 = 'Soweto, South Africa'

geolocator = Nominatim()
location34 = geolocator.geocode(connection34)
latitude34 = location34.latitude
longitude34 = location34.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection34, latitude34, longitude34))


connection35 = 'Umhlanga, South Africa'

geolocator = Nominatim()
location35 = geolocator.geocode(connection35)
latitude35 = location35.latitude
longitude35 = location35.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection35, latitude35, longitude35))


connection36 = 'Amanzimtoti, South Africa'

geolocator = Nominatim()
location36 = geolocator.geocode(connection36)
latitude36 = location36.latitude
longitude36 = location36.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection36, latitude36, longitude36))


connection37 = 'Durban North, South Africa'

geolocator = Nominatim()
location37 = geolocator.geocode(connection37)
latitude37 = location37.latitude
longitude37 = location37.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection37, latitude37, longitude37))


connection38 = 'Durban South, South Africa'

geolocator = Nominatim()
location38 = geolocator.geocode(connection38)
latitude38 = location38.latitude
longitude38 = location38.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection38, latitude38, longitude38))


connection39 = 'Hillcrest, South Africa'

geolocator = Nominatim()
location39 = geolocator.geocode(connection39)
latitude39 = location39.latitude
longitude39 = location39.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection39, latitude39, longitude39))


connection40 = 'Queensburg, South Africa'

geolocator = Nominatim()
location40 = geolocator.geocode(connection40)
latitude40 = location40.latitude
longitude40 = location40.longitude
print('The geograpical coordinate of {} are {}, {}.'.format(connection40, latitude40, longitude40))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:3: DeprecationWarning: Using Nominatim with the default "geopy/1.18.1" `user_agent` is strongly discouraged, as it violates Nominatim's ToS https://operations.osmfoundation.org/policies/nominatim/ and may possibly cause 403 and 429 HTTP errors. Please specify a custom `user_agent` with `Nominatim(user_agent="my-application")` or by overriding the default `user_agent`: `geopy.geocoders.options.default_user_agent = "my-application"`. In geopy 2.0 this will become an exception.
#   app.launch_new_instance()
# ...

# %%
CLIENT_ID = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' # your Foursquare ID
CLIENT_SECRET = 'XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX' # your Foursquare Secret
VERSION = '20200420' # Foursquare API version

print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)


LIMIT = 100 # limit of number of venues returned by Foursquare API
radius = 10000 # define radius

# create URLs
url1 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude1, 
    longitude1, 
    radius, 
    LIMIT)


# create URLs
url2 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude2, 
    longitude2, 
    radius, 
    LIMIT)


# create URLs
url3 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude3, 
    longitude3, 
    radius, 
    LIMIT)

# create URLs
url4 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude4, 
    longitude4, 
    radius, 
    LIMIT)


# create URLs
url5 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude5, 
    longitude5, 
    radius, 
    LIMIT)

# create URLs
url6 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude6, 
    longitude6, 
    radius, 
    LIMIT)


# create URLs
url7 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude7, 
    longitude7, 
    radius, 
    LIMIT)


# create URLs
url8 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude8, 
    longitude8, 
    radius, 
    LIMIT)


# create URLs
url9 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude9, 
    longitude9, 
    radius, 
    LIMIT)


# create URLs
url10 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude10, 
    longitude10, 
    radius, 
    LIMIT)


# create URLs
url11 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude11, 
    longitude11, 
    radius, 
    LIMIT)


# create URLs
url12 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude12, 
    longitude12, 
    radius, 
    LIMIT)

# create URLs
url13 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude13, 
    longitude13, 
    radius, 
    LIMIT)

# create URLs
url14 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude14, 
    longitude14, 
    radius, 
    LIMIT)

# create URLs
url15 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude15, 
    longitude15, 
    radius, 
    LIMIT)

# create URLs
url16 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude16, 
    longitude16, 
    radius, 
    LIMIT)

# create URLs
url17 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude17, 
    longitude17, 
    radius, 
    LIMIT)

# create URLs
url18 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude18, 
    longitude18, 
    radius, 
    LIMIT)

# create URLs
url19 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude19, 
    longitude19, 
    radius, 
    LIMIT)

# create URLs
url20 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude20, 
    longitude20, 
    radius, 
    LIMIT)

# create URLs
url21 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude21, 
    longitude21, 
    radius, 
    LIMIT)


# create URLs
url22 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude22, 
    longitude22, 
    radius, 
    LIMIT)


# create URLs
url23 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude23, 
    longitude23, 
    radius, 
    LIMIT)

# create URLs
url24 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude24, 
    longitude24, 
    radius, 
    LIMIT)


# create URLs
url25 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude25, 
    longitude25, 
    radius, 
    LIMIT)

# create URLs
url26 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude26, 
    longitude26, 
    radius, 
    LIMIT)


# create URLs
url27 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude27, 
    longitude27, 
    radius, 
    LIMIT)


# create URLs
url28 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude28, 
    longitude28, 
    radius, 
    LIMIT)


# create URLs
url29 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude29, 
    longitude29, 
    radius, 
    LIMIT)


# create URLs
url30 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude30, 
    longitude30, 
    radius, 
    LIMIT)

# create URLs
url31 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude31, 
    longitude31, 
    radius, 
    LIMIT)


# create URLs
url32 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude32, 
    longitude32, 
    radius, 
    LIMIT)


# create URLs
url33 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude33, 
    longitude33, 
    radius, 
    LIMIT)

# create URLs
url34 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude34, 
    longitude34, 
    radius, 
    LIMIT)


# create URLs
url35 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude35, 
    longitude35, 
    radius, 
    LIMIT)

# create URLs
url36 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude36, 
    longitude36, 
    radius, 
    LIMIT)


# create URLs
url37 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude37, 
    longitude37, 
    radius, 
    LIMIT)


# create URLs
url38 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude38, 
    longitude38, 
    radius, 
    LIMIT)


# create URLs
url39 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude39, 
    longitude39, 
    radius, 
    LIMIT)


# create URLs
url40 = 'https://api.foursquare.com/v2/venues/explore?&client_id={}&client_secret={}&v={}&ll={},{}&radius={}&limit={}'.format(
    CLIENT_ID, 
    CLIENT_SECRET, 
    VERSION, 
    latitude40, 
    longitude40, 
    radius, 
    LIMIT)



print(url1, url2, url3, url4, url5, url6,url7, url8, url9, url10, 
url11, url12,url13, url14, url15, url16, url17, url18, url19, url20,url21, url22, url23, url24, url25, url26,url27, url28, url29, url30,url31, url32, url33, url34, url35, url36,url37, url38, url39, url40,  )
# Out:
# Your credentails:
# CLIENT_ID: HT20LCBRAAIDOZTF2ENRIEBOJRXOH4AZ4T1H40SF5M4ZMT3M
# CLIENT_SECRET:GZVZXXCWZ1SFH3I4HXFCW4CHD31XOSEWQPL5V4XVPUEDHLIH
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-32-1a4303001875> in <module>
#     195     CLIENT_SECRET,
#     196     VERSION,
# --> 197     latitude18,
#     198     longitude18,
#     199     radius,
#
# NameError: name 'latitude18' is not defined

# %%
results1 = requests.get(url1).json()
results1

results2 = requests.get(url2).json()
results2

results3 = requests.get(url3).json()
results3

results4 = requests.get(url4).json()
results4

results5 = requests.get(url5).json()
results5

results6 = requests.get(url6).json()
results6

results7 = requests.get(url7).json()
results7

results8 = requests.get(url8).json()
results8

results9 = requests.get(url9).json()
results9

results10 = requests.get(url10).json()
results10

results11 = requests.get(url11).json()
results11

results12 = requests.get(url12).json()
results12

results13 = requests.get(url13).json()
results13

results14 = requests.get(url14).json()
results14

results15 = requests.get(url15).json()
results15

results16 = requests.get(url16).json()
results16

results17 = requests.get(url17).json()
results17

results18 = requests.get(url18).json()
results18

results19 = requests.get(url19).json()
results19

results20 = requests.get(url20).json()
results20

results21 = requests.get(url21).json()
results21

results22 = requests.get(url22).json()
results22

results23 = requests.get(url23).json()
results23

results24 = requests.get(url24).json()
results24

results25 = requests.get(url25).json()
results25

results26 = requests.get(url26).json()
results26

results27 = requests.get(url27).json()
results27

results28 = requests.get(url28).json()
results28

results29 = requests.get(url29).json()
results29

results30 = requests.get(url30).json()
results30

results31 = requests.get(url31).json()
results31

results32 = requests.get(url32).json()
results32

results33 = requests.get(url33).json()
results33

results34 = requests.get(url34).json()
results34

results35 = requests.get(url35).json()
results35

results36 = requests.get(url36).json()
results36

results37 = requests.get(url37).json()
results37

results38 = requests.get(url38).json()
results38

results39 = requests.get(url39).json()
results39

results40 = requests.get(url40).json()
results40
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-33-4557209219d7> in <module>
#      50 results17
#      51
# ---> 52 results18 = requests.get(url18).json()
#      53 results18
#      54
#
# NameError: name 'url18' is not defined

# %%
# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']
    

### 1st city ###    
    
venues1 = results1['response']['groups'][0]['items']
nearby_venues1 = json_normalize(venues1) # flatten JSON

venues1 = results1['response']['groups'][0]['items']
nearby_venues1 = json_normalize(venues1) # flatten JSON

# filter columns
filtered_columns1 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues1 =nearby_venues1.loc[:, filtered_columns1]

# filter the category for each row
nearby_venues1['venue.categories'] = nearby_venues1.apply(get_category_type, axis=1)

# clean columns
nearby_venues1.columns = [col.split(".")[-1] for col in nearby_venues1.columns]


### 2nd city ###

venues2 = results2['response']['groups'][0]['items']
nearby_venues2 = json_normalize(venues2) # flatten JSON

# filter columns
filtered_columns2 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues2 =nearby_venues2.loc[:, filtered_columns2]

# filter the category for each row
nearby_venues2['venue.categories'] = nearby_venues2.apply(get_category_type, axis=1)

# clean columns
nearby_venues2.columns = [col.split(".")[-1] for col in nearby_venues2.columns]


### 3rd city ###

venues3 = results3['response']['groups'][0]['items']
nearby_venues3 = json_normalize(venues3) # flatten JSON

# filter columns
filtered_columns3 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues3 =nearby_venues3.loc[:, filtered_columns3]

# filter the category for each row
nearby_venues3['venue.categories'] = nearby_venues3.apply(get_category_type, axis=1)

# clean columns
nearby_venues3.columns = [col.split(".")[-1] for col in nearby_venues3.columns]


### 4th city ###

venues4 = results4['response']['groups'][0]['items']
nearby_venues4 = json_normalize(venues4) # flatten JSON

# filter columns
filtered_columns4 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues4 =nearby_venues4.loc[:, filtered_columns4]

# filter the category for each row
nearby_venues4['venue.categories'] = nearby_venues4.apply(get_category_type, axis=1)

# clean columns
nearby_venues4.columns = [col.split(".")[-1] for col in nearby_venues4.columns]



### fifth city ###

venues5 = results5['response']['groups'][0]['items']
nearby_venues5 = json_normalize(venues5) # flatten JSON

# filter columns
filtered_columns5 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues5 =nearby_venues5.loc[:, filtered_columns5]

# filter the category for each row
nearby_venues5['venue.categories'] = nearby_venues5.apply(get_category_type, axis=1)

# clean columns
nearby_venues5.columns = [col.split(".")[-1] for col in nearby_venues5.columns]



### sixth city ###

venues6 = results6['response']['groups'][0]['items']
nearby_venues6 = json_normalize(venues6) # flatten JSON

# filter columns
filtered_columns6 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues6 =nearby_venues6.loc[:, filtered_columns6]

# filter the category for each row
nearby_venues6['venue.categories'] = nearby_venues6.apply(get_category_type, axis=1)

# clean columns
nearby_venues6.columns = [col.split(".")[-1] for col in nearby_venues6.columns]




### seventh city ###

venues7 = results7['response']['groups'][0]['items']
nearby_venues7 = json_normalize(venues7) # flatten JSON

# filter columns
filtered_columns7 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues7 =nearby_venues7.loc[:, filtered_columns7]

# filter the category for each row
nearby_venues7['venue.categories'] = nearby_venues7.apply(get_category_type, axis=1)

# clean columns
nearby_venues7.columns = [col.split(".")[-1] for col in nearby_venues7.columns]



### sixth city ###

venues8 = results8['response']['groups'][0]['items']
nearby_venues8 = json_normalize(venues8) # flatten JSON

# filter columns
filtered_columns8 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues8 =nearby_venues8.loc[:, filtered_columns8]

# filter the category for each row
nearby_venues8['venue.categories'] = nearby_venues8.apply(get_category_type, axis=1)

# clean columns
nearby_venues8.columns = [col.split(".")[-1] for col in nearby_venues8.columns]




### sixth city ###

venues9 = results9['response']['groups'][0]['items']
nearby_venues9 = json_normalize(venues9) # flatten JSON

# filter columns
filtered_columns9 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues9 =nearby_venues9.loc[:, filtered_columns9]

# filter the category for each row
nearby_venues9['venue.categories'] = nearby_venues9.apply(get_category_type, axis=1)

# clean columns
nearby_venues9.columns = [col.split(".")[-1] for col in nearby_venues9.columns]




### 5th city ###

venues10 = results10['response']['groups'][0]['items']
nearby_venues10 = json_normalize(venues10) # flatten JSON

# filter columns
filtered_columns10 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues10 =nearby_venues10.loc[:, filtered_columns10]

# filter the category for each row
nearby_venues10['venue.categories'] = nearby_venues10.apply(get_category_type, axis=1)

# clean columns
nearby_venues10.columns = [col.split(".")[-1] for col in nearby_venues10.columns]


### sixth city ###

venues11 = results11['response']['groups'][0]['items']
nearby_venues11 = json_normalize(venues11) # flatten JSON

# filter columns
filtered_columns11 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues11 =nearby_venues11.loc[:, filtered_columns11]

# filter the category for each row
nearby_venues11['venue.categories'] = nearby_venues11.apply(get_category_type, axis=1)

# clean columns
nearby_venues11.columns = [col.split(".")[-1] for col in nearby_venues11.columns]


### sixth city ###

venues12 = results12['response']['groups'][0]['items']
nearby_venues12 = json_normalize(venues12) # flatten JSON

# filter columns
filtered_columns12 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues12 =nearby_venues12.loc[:, filtered_columns12]

# filter the category for each row
nearby_venues12['venue.categories'] = nearby_venues12.apply(get_category_type, axis=1)
# clean columns
nearby_venues12.columns = [col.split(".")[-1] for col in nearby_venues12.columns]


venues13 = results13['response']['groups'][0]['items']
nearby_venues13 = json_normalize(venues13) # flatten JSON

# filter columns
filtered_columns13 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues13 =nearby_venues13.loc[:, filtered_columns13]

# filter the category for each row
nearby_venues13['venue.categories'] = nearby_venues13.apply(get_category_type, axis=1)

# clean columns
nearby_venues13.columns = [col.split(".")[-1] for col in nearby_venues13.columns]


venues14 = results14['response']['groups'][0]['items']
nearby_venues14 = json_normalize(venues14) # flatten JSON

# filter columns
filtered_columns14 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues14 =nearby_venues14.loc[:, filtered_columns14]

# filter the category for each row
nearby_venues14['venue.categories'] = nearby_venues14.apply(get_category_type, axis=1)

# clean columns
nearby_venues14.columns = [col.split(".")[-1] for col in nearby_venues14.columns]



venues15 = results15['response']['groups'][0]['items']
nearby_venues15 = json_normalize(venues15) # flatten JSON

# filter columns
filtered_columns15 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues15 =nearby_venues15.loc[:, filtered_columns15]

# filter the category for each row
nearby_venues15['venue.categories'] = nearby_venues15.apply(get_category_type, axis=1)

# clean columns
nearby_venues15.columns = [col.split(".")[-1] for col in nearby_venues15.columns]



venues16 = results16['response']['groups'][0]['items']
nearby_venues16 = json_normalize(venues16) # flatten JSON

# filter columns
filtered_columns16 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues16 =nearby_venues16.loc[:, filtered_columns16]

# filter the category for each row
nearby_venues16['venue.categories'] = nearby_venues16.apply(get_category_type, axis=1)

# clean columns
nearby_venues16.columns = [col.split(".")[-1] for col in nearby_venues16.columns]



venues17 = results17['response']['groups'][0]['items']
nearby_venues17 = json_normalize(venues17) # flatten JSON

# filter columns
filtered_columns17 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues17 =nearby_venues17.loc[:, filtered_columns17]

# filter the category for each row
nearby_venues17['venue.categories'] = nearby_venues17.apply(get_category_type, axis=1)

# clean columns
nearby_venues17.columns = [col.split(".")[-1] for col in nearby_venues17.columns]



venues18 = results18['response']['groups'][0]['items']
nearby_venues18 = json_normalize(venues18) # flatten JSON

# filter columns
filtered_columns18 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues18 =nearby_venues18.loc[:, filtered_columns18]

# filter the category for each row
nearby_venues18['venue.categories'] = nearby_venues18.apply(get_category_type, axis=1)

# clean columns
nearby_venues18.columns = [col.split(".")[-1] for col in nearby_venues18.columns]



venues19 = results19['response']['groups'][0]['items']
nearby_venues19 = json_normalize(venues19) # flatten JSON

# filter columns
filtered_columns19 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues19 =nearby_venues19.loc[:, filtered_columns19]

# filter the category for each row
nearby_venues19['venue.categories'] = nearby_venues19.apply(get_category_type, axis=1)

# clean columns
nearby_venues19.columns = [col.split(".")[-1] for col in nearby_venues19.columns]



venues20 = results20['response']['groups'][0]['items']
nearby_venues20 = json_normalize(venues20) # flatten JSON

# filter columns
filtered_columns20 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']

# filter the category for each row
nearby_venues20['venue.categories'] = nearby_venues20.apply(get_category_type, axis=1)

# clean columns
nearby_venues20.columns = [col.split(".")[-1] for col in nearby_venues20.columns]


### 21st city ###    

venues21 = results21['response']['groups'][0]['items']
nearby_venues21 = json_normalize(venues21) # flatten JSON

# filter columns
filtered_columns21 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues21 =nearby_venues21.loc[:, filtered_columns21]

# filter the category for each row
nearby_venues21['venue.categories'] = nearby_venues21.apply(get_category_type, axis=1)

# clean columns
nearby_venues21.columns = [col.split(".")[-1] for col in nearby_venues21.columns]


### 22nd city ###

venues22 = results22['response']['groups'][0]['items']
nearby_venues22 = json_normalize(venues22) # flatten JSON

# filter columns
filtered_columns22 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues22 =nearby_venues22.loc[:, filtered_columns22]

# filter the category for each row
nearby_venues22['venue.categories'] = nearby_venues22.apply(get_category_type, axis=1)

# clean columns
nearby_venues22.columns = [col.split(".")[-1] for col in nearby_venues22.columns]


### 3rd city ###

venues23 = results23['response']['groups'][0]['items']
nearby_venues23 = json_normalize(venues23) # flatten JSON

# filter columns
filtered_columns23 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues23 =nearby_venues23.loc[:, filtered_columns23]

# filter the category for each row
nearby_venues23['venue.categories'] = nearby_venues23.apply(get_category_type, axis=1)

# clean columns
nearby_venues23.columns = [col.split(".")[-1] for col in nearby_venues23.columns]


### 24th city ###

venues24 = results24['response']['groups'][0]['items']
nearby_venues24 = json_normalize(venues24) # flatten JSON

# filter columns
filtered_columns24 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues24 =nearby_venues24.loc[:, filtered_columns24]

# filter the category for each row
nearby_venues24['venue.categories'] = nearby_venues24.apply(get_category_type, axis=1)

# clean columns
nearby_venues24.columns = [col.split(".")[-1] for col in nearby_venues24.columns]



### fifth city ###

venues25 = results25['response']['groups'][0]['items']
nearby_venues25 = json_normalize(venues25) # flatten JSON

# filter columns
filtered_columns25 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues25 =nearby_venues25.loc[:, filtered_columns25]

# filter the category for each row
nearby_venues25['venue.categories'] = nearby_venues25.apply(get_category_type, axis=1)

# clean columns
nearby_venues25.columns = [col.split(".")[-1] for col in nearby_venues25.columns]



### 26th city ###

venues26 = results26['response']['groups'][0]['items']
nearby_venues26 = json_normalize(venues26) # flatten JSON

# filter columns
filtered_columns26 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues26 =nearby_venues26.loc[:, filtered_columns26]

# filter the category for each row
nearby_venues26['venue.categories'] = nearby_venues26.apply(get_category_type, axis=1)

# clean columns
nearby_venues26.columns = [col.split(".")[-1] for col in nearby_venues26.columns]




### seventh city ###

venues27 = results27['response']['groups'][0]['items']
nearby_venues27 = json_normalize(venues7) # flatten JSON

# filter columns
filtered_columns27 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues27 =nearby_venues27.loc[:, filtered_columns27]

# filter the category for each row
nearby_venues27['venue.categories'] = nearby_venues27.apply(get_category_type, axis=1)

# clean columns
nearby_venues27.columns = [col.split(".")[-1] for col in nearby_venues27.columns]



### sixth city ###

venues28 = results28['response']['groups'][0]['items']
nearby_venues28 = json_normalize(venues28) # flatten JSON

# filter columns
filtered_columns28 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues28 =nearby_venues28.loc[:, filtered_columns28]

# filter the category for each row
nearby_venues28['venue.categories'] = nearby_venues28.apply(get_category_type, axis=1)

# clean columns
nearby_venues28.columns = [col.split(".")[-1] for col in nearby_venues28.columns]

#clean


venues29 = results29['response']['groups'][0]['items']
nearby_venues29 = json_normalize(venues29) # flatten JSON

# filter columns
filtered_columns29 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                   'venue.location.lng', 'venue.id']
nearby_venues29 =nearby_venues29.loc[:, filtered_columns29]

# filter the category for each row
nearby_venues29['venue.categories'] = nearby_venues29.apply(get_category_type, axis=1)

# clean columns
nearby_venues29.columns = [col.split(".")[-1] for col in nearby_venues29.columns]


### 5th city ###

venues30 = results30['response']['groups'][0]['items']
nearby_venues30 = json_normalize(venues30) # flatten JSON

# filter columns
filtered_columns30 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues30 =nearby_venues30.loc[:, filtered_columns30]

# filter the category for each row
nearby_venues30['venue.categories'] = nearby_venues30.apply(get_category_type, axis=1)

# clean columns
nearby_venues30.columns = [col.split(".")[-1] for col in nearby_venues30.columns]

### 1st city ###    
    
venues31 = results31['response']['groups'][0]['items']
nearby_venues31 = json_normalize(venues31) # flatten JSON

venues31 = results31['response']['groups'][0]['items']
nearby_venues31 = json_normalize(venues31) # flatten JSON

# filter columns
filtered_columns31 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues31 =nearby_venues31.loc[:, filtered_columns31]

# filter the category for each row
nearby_venues31['venue.categories'] = nearby_venues31.apply(get_category_type, axis=1)

# clean columns
nearby_venues31.columns = [col.split(".")[-1] for col in nearby_venues31.columns]


### 2nd city ###

venues32 = results32['response']['groups'][0]['items']
nearby_venues32 = json_normalize(venues32) # flatten JSON

# filter columns
filtered_columns32 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues32 =nearby_venues32.loc[:, filtered_columns32]

# filter the category for each row
nearby_venues32['venue.categories'] = nearby_venues32.apply(get_category_type, axis=1)

# clean columns
nearby_venues32.columns = [col.split(".")[-1] for col in nearby_venues32.columns]


### 3rd city ###

venues33 = results33['response']['groups'][0]['items']
nearby_venues33 = json_normalize(venues33) # flatten JSON

# filter columns
filtered_columns33 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues33 =nearby_venues33.loc[:, filtered_columns33]

# filter the category for each row
nearby_venues33['venue.categories'] = nearby_venues33.apply(get_category_type, axis=1)

# clean columns
nearby_venues33.columns = [col.split(".")[-1] for col in nearby_venues33.columns]


### 4th city ###

venues34 = results34['response']['groups'][0]['items']
nearby_venues34 = json_normalize(venues34) # flatten JSON

# filter columns
filtered_columns34 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues34 =nearby_venues34.loc[:, filtered_columns34]

# filter the category for each row
nearby_venues34['venue.categories'] = nearby_venues34.apply(get_category_type, axis=1)

# clean columns
nearby_venues34.columns = [col.split(".")[-1] for col in nearby_venues34.columns]



### fifth city ###

#venues35 = results35['response']['groups'][0]['items']
#nearby_venues35 = json_normalize(venues35) # flatten JSON

# filter columns
#filtered_columns35 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
 #                   'venue.location.lng', 'venue.id'] 
#nearby_venues35 = nearby_venues35.loc[:, filtered_columns35]


# filter the category for each row
#nearby_venues35['venue.categories'] = nearby_venues35.apply(get_category_type, axis=1)

# clean columns
#nearby_venues35.columns = [col.split(".")[-1] for col in nearby_venues35.columns]



### sixth city ###

venues36 = results36['response']['groups'][0]['items']
nearby_venues36 = json_normalize(venues36) # flatten JSON

# filter columns
filtered_columns36 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues36 = nearby_venues36.loc[:, filtered_columns36]

# filter the category for each row
nearby_venues36['venue.categories'] = nearby_venues36.apply(get_category_type, axis=1)

# clean columns
nearby_venues36.columns = [col.split(".")[-1] for col in nearby_venues36.columns]




### seventh city ###

venues37 = results37['response']['groups'][0]['items']
nearby_venues37 = json_normalize(venues37) # flatten JSON

# filter columns
filtered_columns37 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues37 =nearby_venues37.loc[:, filtered_columns37]

# filter the category for each row
nearby_venues37['venue.categories'] = nearby_venues37.apply(get_category_type, axis=1)

# clean columns
nearby_venues37.columns = [col.split(".")[-1] for col in nearby_venues37.columns]



### sixth city ###

venues38 = results38['response']['groups'][0]['items']
nearby_venues38 = json_normalize(venues38) # flatten JSON

# filter columns
filtered_columns38 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues38 =nearby_venues38.loc[:, filtered_columns38]

# filter the category for each row
nearby_venues38['venue.categories'] = nearby_venues38.apply(get_category_type, axis=1)

# clean columns
nearby_venues38.columns = [col.split(".")[-1] for col in nearby_venues38.columns]




### sixth city ###

venues39 = results39['response']['groups'][0]['items']
nearby_venues39 = json_normalize(venues39) # flatten JSON

# filter columns
filtered_columns39 = ['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues39 =nearby_venues39.loc[:, filtered_columns39]

# filter the category for each row
nearby_venues39['venue.categories'] = nearby_venues39.apply(get_category_type, axis=1)

# clean columns
nearby_venues39.columns = [col.split(".")[-1] for col in nearby_venues39.columns]




### 5th city ###

venues40 = results40['response']['groups'][0]['items']
nearby_venues40 = json_normalize(venues40) # flatten JSON

# filter columns
filtered_columns40 =['venue.location.postalCode','venue.name', 'venue.categories', 'venue.location.lat', 
                    'venue.location.lng', 'venue.id']
nearby_venues40 = nearby_venues40.loc[:, filtered_columns40]

# filter the category for each row
nearby_venues40['venue.categories'] = nearby_venues40.apply(get_category_type, axis=1)

# clean columns
nearby_venues40.columns = [col.split(".")[-1] for col in nearby_venues40.columns]


print('{} venues were returned by Foursquare.'.format(nearby_venues1.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues2.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues3.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues4.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues5.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues6.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues7.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues8.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues9.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues10.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues11.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues12.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues13.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues14.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues15.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues16.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues17.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues18.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues19.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues20.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues21.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues22.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues23.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues24.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues25.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues26.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues27.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues28.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues29.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues30.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues31.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues32.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues33.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues34.shape[0]))
#print('{} venues were returned by Foursquare.'.format(nearby_venues35.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues36.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues37.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues38.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues39.shape[0]))
print('{} venues were returned by Foursquare.'.format(nearby_venues40.shape[0]))
# Out:
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:17: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:20: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:37: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:54: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# /opt/conda/envs/Python36/lib/python3.6/site-packages/ipykernel/__main__.py:71: FutureWarning: pandas.io.json.json_normalize is deprecated, use pandas.json_normalize instead
# ...

# %%
# add locations data to the data sets of each city

nearby_venues1['City'] = 'False Bay-Cape Town'
nearby_venues2['City'] = 'Bellville-Cape Town'
nearby_venues3['City'] = 'City Bowl-Cape Town'
nearby_venues4['City'] = 'Atlantic Seaboard-Cape Town'
nearby_venues5['City'] = 'Goodwood-Cape Town'
nearby_venues6['City'] = 'Brackenfell-Cape Town'
nearby_venues7['City'] = 'Simons Town-Cape Town'
nearby_venues8['City'] = 'Hout Bay-Cape Town'
nearby_venues9['City'] = 'Green Point-Cape Town'
nearby_venues10['City'] ='Ocean View-Cape Town'
nearby_venues11['City'] = 'Table View-Cape Town'
nearby_venues12['City'] = 'Parow-Cape Town'
nearby_venues13['City'] = 'Durbanville-Cape Town'
nearby_venues14['City'] = 'Muizenberg-Cape Town'
nearby_venues15['City'] = 'South Surburbs-Cape Town'
nearby_venues16['City'] = 'Milnerton-Cape Town'
nearby_venues17['City'] = 'Wynberg-Cape Town'
nearby_venues18['City'] = 'Bedfordview-Johannesburg'
nearby_venues19['City'] = 'Blouberg-Johannesburg'
nearby_venues20['City'] = 'Kuils River Cape Town'
nearby_venues21['City'] = 'Randburg-Johannesburg'
nearby_venues22['City'] = 'Fourways-Johannesburg'
nearby_venues23['City'] = 'Rivonia-Johannesburg'
nearby_venues24['City'] = 'Johanneburg CBD-Johannesburg'
nearby_venues25['City'] = 'Bruma-Johannesburg'
nearby_venues26['City'] = 'Johannesburg South-Johannesburg'
nearby_venues27['City'] = 'Northcliff-Johannesburg'
nearby_venues28['City'] = 'Nothriding-Johannesburg'
nearby_venues29['City'] = 'Lanseria-Johannesburg'
nearby_venues30['City'] = 'Rose Bank-Johannesburg'
nearby_venues31['City'] = 'Parktown-Johannesburg'
nearby_venues32['City'] = 'Sandton-Johannesburg'
nearby_venues33['City'] = 'Ferndale-Johannesburg'
nearby_venues34['City'] = 'Soweto-Johannesburg'
#nearby_venues35['City'] = 'Umhlanga'
nearby_venues36['City'] = 'Amanzimtoti-Durban'
nearby_venues37['City'] = 'Durban North-Durban'
nearby_venues38['City'] = 'Durban South-Durban'
nearby_venues39['City'] = 'Hillcrest-Durban'
nearby_venues40['City'] = 'Queensburg-Durban'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-35-52b370374ff6> in <module>
#      18 nearby_venues16['City'] = 'Milnerton-Cape Town'
#      19 nearby_venues17['City'] = 'Wynberg-Cape Town'
# ---> 20 nearby_venues18['City'] = 'Bedfordview-Johannesburg'
#      21 nearby_venues19['City'] = 'Blouberg-Johannesburg'
#      22 nearby_venues20['City'] = 'Kuils River Cape Town'
#
# NameError: name 'nearby_venues18' is not defined

# %%
# combine the three cities into one data set

nearby_venues = nearby_venues1.copy()
nearby_venues = nearby_venues.append(nearby_venues2)
nearby_venues = nearby_venues.append(nearby_venues3)
nearby_venues = nearby_venues.append(nearby_venues4)
nearby_venues = nearby_venues.append(nearby_venues5)
nearby_venues = nearby_venues.append(nearby_venues6)
nearby_venues = nearby_venues.append(nearby_venues7)
nearby_venues = nearby_venues.append(nearby_venues8)
nearby_venues = nearby_venues.append(nearby_venues9)
nearby_venues = nearby_venues.append(nearby_venues10)
nearby_venues = nearby_venues.append(nearby_venues11)
nearby_venues = nearby_venues.append(nearby_venues12)
nearby_venues = nearby_venues.append(nearby_venues13)
nearby_venues = nearby_venues.append(nearby_venues14)
nearby_venues = nearby_venues.append(nearby_venues15)
nearby_venues = nearby_venues.append(nearby_venues16)
nearby_venues = nearby_venues.append(nearby_venues17)
nearby_venues = nearby_venues.append(nearby_venues18)
nearby_venues = nearby_venues.append(nearby_venues19)
#nearby_venues = nearby_venues.append(nearby_venues20)
nearby_venues = nearby_venues.append(nearby_venues21)
nearby_venues = nearby_venues.append(nearby_venues22)
nearby_venues = nearby_venues.append(nearby_venues23)
nearby_venues = nearby_venues.append(nearby_venues24)
nearby_venues = nearby_venues.append(nearby_venues25)
nearby_venues = nearby_venues.append(nearby_venues26)
nearby_venues = nearby_venues.append(nearby_venues27)
nearby_venues = nearby_venues.append(nearby_venues28)
nearby_venues = nearby_venues.append(nearby_venues29)
nearby_venues = nearby_venues.append(nearby_venues30)
nearby_venues = nearby_venues.append(nearby_venues31)
nearby_venues = nearby_venues.append(nearby_venues32)
nearby_venues = nearby_venues.append(nearby_venues33)
nearby_venues = nearby_venues.append(nearby_venues34)
#nearby_venues = nearby_venues.append(nearby_venues35)
nearby_venues = nearby_venues.append(nearby_venues36)
nearby_venues = nearby_venues.append(nearby_venues37)
nearby_venues = nearby_venues.append(nearby_venues38)
nearby_venues = nearby_venues.append(nearby_venues39)
nearby_venues = nearby_venues.append(nearby_venues40)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-36-9fb4fe8aa628> in <module>
#      18 nearby_venues = nearby_venues.append(nearby_venues16)
#      19 nearby_venues = nearby_venues.append(nearby_venues17)
# ---> 20 nearby_venues = nearby_venues.append(nearby_venues18)
#      21 nearby_venues = nearby_venues.append(nearby_venues19)
#      22 #nearby_venues = nearby_venues.append(nearby_venues20)
#
# NameError: name 'nearby_venues18' is not defined

# %%
# check list and manually remove all non-restaurant data

nearby_venues['categories']

removal_list = ['Concert Hall', 'Opera House', 'Dance Studio','Fun'
                'Performing Arts Venue', 'Art Museum', 'Park',
                'Massage Studio', 'Music Venue', 'Bookstore', 'Clothing Store',
                'Boutique', 'Furniture/Home Store', 'Jazz Club',
                'Theater', 'Optical Shop', "Men's Store", 'Rock Club',
                'Gym / Fitness Center', 'Wine Shop', 'Indie Movie Theater',
                'Chocolate Shop', 'Dessert Shop', 'Recreation Center', 
                'Plaza', 'Hotel', 'Luggage Store', 'Farmers Market', 'Gym',
                'Jewelry Store', 'Furniture / Home Store', 'Butcher', 
                'Bakery', 'Marijuana Dispensary', 'Ice Cream Shop',
                'Comic Shop', 'Bagel Shop', 'Spa', 'Liquor Store', 'Bike Shop',
                'Yoga Studio', 'Pedestrian Plaza', 'Candy Store',
                'Park', 'Bookstore', 'Candy Store',  'Jazz Club', 'Art Gallery', 
                 'Supermarket', 'Museum', 'Boutique', 'Plaza', 'Building', 'Bakery',
                 'Historic Site', 'Ice Cream Shop', ' Concert Hall', 'Pharmacy', 
                 'Market', 'Movie Theater', 'Performing Arts Venue', 'Music Venue',
                 'Theater', 'Art Museum', 'Cheese Shop', 'Opera House',
                 'Pedestrian Plaza', 'School', 'Gift Shop', 'Athletics & Sports',
                 'Shoe Repair', 'General Entertainment', 'Stationery Store',
                 'Toy / Game Store', 'Brewery', 'Hotel', 'Theater', 'Music Venue', 'Business Service',
                 'Donut Shop', 'Liquor Store', 'Beer Store',
                 'Lounge', 'Plaza', 'Health Food Store', 'Concert Hall', 
                 'Lingerie Store', 'Gym', 'Mobile Phone Shop',
                 'Chocolate Shop', 'Ice Cream Shop', 'Hostel', 'Convenience Store', 
                 'Park', 'Farmers Market', 'Cosmetics Shop', 'Piano Bar',
                 'Nightclub', 'Massage Studio', 'Comedy Club', 'Concert Hall']

#nearby_venues = nearby_venues[~nearby_venues['categories'].isin(removal_list)]

nearby_venues['categories'].tolist()
# Out:
# ['Beach',
#  'Scenic Lookout',
#  'Department Store',
#  'Pharmacy',
#  'Café',
#  'Gym',
#  'Café',
#  'Electronics Store',
#  'Supermarket',
#  'Bakery',
#  'Burger Joint',
#  'Coffee Shop',
#  'Pizza Place',
#  'Bookstore',
#  'Deli / Bodega',
#  'Shopping Mall',
#  'Steakhouse',
#  'Food & Drink Shop',
#  'Office',
#  'Pizza Place',
#  'Sushi Restaurant',
#  'Shopping Mall',
#  'Scenic Lookout',
#  'Coffee Shop',
#  'Coffee Shop',
#  'Convenience Store',
#  'Coffee Shop',
#  'Burger Joint',
#  'Theater',
#  'Steakhouse',
#  'Fast Food Restaurant',
#  'Grocery Store',
#  'Bistro',
#  'Restaurant',
#  'Supermarket',
#  'Steakhouse',
#  'Gym',
#  'Grocery Store',
#  'Flower Shop',
#  'Gastropub',
#  'Winery',
#  'Multiplex',
#  'Shopping Mall',
#  'Cocktail Bar',
#  'Restaurant',
#  'Sushi Restaurant',
#  'Music Venue',
#  'Shopping Mall',
#  'Grocery Store',
#  'Breakfast Spot',
#  'Grocery Store',
#  'Department Store',
#  'Vineyard',
#  'Tapas Restaurant',
# ...

# %%
# this is really the raw dataset now so let us rename it something more appropriate

Bset_Tourist_Venues = nearby_venues
Bset_Tourist_Venues2.to_csv('SA Top Best Venues For Tourists.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-39-46114ea6fc70> in <module>
#       2
#       3 Bset_Tourist_Venues = nearby_venues
# ----> 4 Bset_Tourist_Venues2.to_csv('SA Top Best Venues For Tourists.csv')
#
# NameError: name 'Bset_Tourist_Venues2' is not defined

# %%
Bset_Tourist_Venues2.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-38-85e8045e9223> in <module>
# ----> 1 Bset_Tourist_Venues2.shape
#
# NameError: name 'Bset_Tourist_Venues2' is not defined

# %%
Bset_Tourist_Venues['categories']

# %% [markdown]
# The Dataset has been save as "Bset_Tourist_Venues" and uploaded in the IBM cloud, and this is how it look like id we read the data frame

# %%
import types
import pandas as pd
from botocore.client import Config
import ibm_boto3

def __iter__(self): return 0

# @hidden_cell
# The following code accesses a file in your IBM Cloud Object Storage. It includes your credentials.
# You might want to remove those credentials before you share the notebook.
client_60e13c7779e54047a47c9140a33d2aa9 = ibm_boto3.client(service_name='s3',
    ibm_api_key_id='lsb1d4OUMlK15pylVa1Z_FqMDWWlj2LyngLvuOMChk9O',
    ibm_auth_endpoint="https://iam.eu-gb.bluemix.net/oidc/token",
    config=Config(signature_version='oauth'),
    endpoint_url='https://s3.eu-geo.objectstorage.service.networklayer.com')
body = client_60e13c7779e54047a47c9140a33d2aa9.get_object(Bucket='peergradedassignmentcapstoneproje-donotdelete-pr-gqe9vywtj8nzlc',Key='SA Top Best Venues For Tourists1.csv')['Body']
# add missing __iter__ method, so pandas accepts body as file-like object
if not hasattr(body, "__iter__"): body.__iter__ = types.MethodType( __iter__, body )

# If you are reading an Excel file into a pandas DataFrame, replace `read_csv` by `read_excel` in the next statement.
Bset_Tourist_Venues = pd.read_csv(body)
Bset_Tourist_Venues.head(10)
# Out:
#    Unnamed: 0 postalCode                            name         categories  \
# 0           0       7974                   Vishoek Beach              Beach
# 1           1       7975                     Seal Island     Scenic Lookout
# 2           0        NaN                      Woolworths   Department Store
# 3           1       7530                           M-Kem           Pharmacy
# 4           2        NaN                 Ou Meul Bakkery               Café
# 5           3       7530       Virgin Active Health Club                Gym
# 6           4        NaN                    Vida E Caffè               Café
# 7           5        NaN  Orms Pro Photo Warehouse North  Electronics Store
# 8           6       7530             Food Lover's Market        Supermarket
# 9           7        NaN                   Limnos Bakery             Bakery
#
#          lat        lng                        id Neighborhood       City
# ...

# %% [markdown]
# Looking at some categories like city

# %%
Bset_Tourist_Venues.loc[Bset_Tourist_Venues['City'] == 'Cape Town']
# Out:
#       Unnamed: 0    postalCode  \
# 0              0          7974
# 1              1          7975
# 2              0           NaN
# 3              1          7530
# 4              2           NaN
# 5              3          7530
# 6              4           NaN
# 7              5           NaN
# 8              6          7530
# 9              7           NaN
# 10             8           NaN
# 11             9           NaN
# 12            10          8001
# 13            11          7530
# 14            12          7550
# 15            13           NaN
# 16            14          7530
# 17            15           NaN
# 18            16          7530
# 19            17           NaN
# 20            18           NaN
# 21            19          7530
# 22            20           NaN
# 23            21          7530
# 24            22          7530
# 25            23          7357
# 26            24           NaN
# 27            25           NaN
# 28            26           NaN
# ...

# %% [markdown]
# The shape of the data

# %%
Bset_Tourist_Venues.shape
# Out:
# (3254, 9)

# %%
Bset_Tourist_Venues.info
# Out:
# <bound method DataFrame.info of       Unnamed: 0    postalCode  \
# 0              0          7974
# 1              1          7975
# 2              0           NaN
# 3              1          7530
# 4              2           NaN
# 5              3          7530
# 6              4           NaN
# 7              5           NaN
# 8              6          7530
# 9              7           NaN
# 10             8           NaN
# 11             9           NaN
# 12            10          8001
# 13            11          7530
# 14            12          7550
# 15            13           NaN
# 16            14          7530
# 17            15           NaN
# 18            16          7530
# 19            17           NaN
# 20            18           NaN
# 21            19          7530
# 22            20           NaN
# 23            21          7530
# 24            22          7530
# 25            23          7357
# 26            24           NaN
# 27            25           NaN
# ...

# %% [markdown]
# The data still needs some more processing before it is suitable for analysis and model training and testing. Mainly, we will explore the data into much dedtail to find hidden paterns that will help the company to make all the important decisions.
